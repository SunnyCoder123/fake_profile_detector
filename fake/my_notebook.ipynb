# %% [markdown]
# ## Loading Datasets

# %%
pip install gender-guesser
# Out:
# Requirement already satisfied: gender-guesser in c:\users\sunny kumar\anaconda3\lib\site-packages (0.4.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install gender-guesser
# Out:
# Requirement already satisfied: gender-guesser in c:\users\sunny kumar\anaconda3\lib\site-packages (0.4.0)

# %%
import pandas as pd
import numpy as np
import re
import gender_guesser.detector as gender

# %%
real_users = pd.read_csv('realusers.csv')
fake_users = pd.read_csv('fakeusers.csv')

# %%
print(real_users.shape)
print(fake_users.shape)
# Out:
# (1481, 41)
# (1337, 41)

# %% [markdown]
# DATA PREPROCESSING

# %% [markdown]
# # Concatenate(Join) both datasets into a single dataset
# X = pd.concat([real_users, fake_users])
# X

# %%
# Concatenate(Join) both datasets into a single dataset
X = pd.concat([real_users, fake_users])
X
# Out:
#       Unnamed: 0          id              name      screen_name  \
# 0              0     3610511  Davide Dellacasa           braddd
# 1              1     5656162    Simone Economo            eKoeS
# 2              2     5682702            tacone          tacone_
# 3              3     6067292          alesaura         alesstar
# 4              4     6015122            Angelo       PerDiletto
# ...          ...         ...               ...              ...
# 1332        1332  1391497074       Verda Marks      VerdaMarks1
# 1333        1333  1391544607   Danial Campbell  DanialCampbell2
# 1334        1334  1391622127      Maudie Meyer     MaudieMeyer1
# 1335        1335  1391832212   Harriett Harvey  HarriettHarvey9
# 1336        1336  1391998039   Gillian Wheeler  GillianWheeler3
#
#       statuses_count  followers_count  friends_count  favourites_count  \
# 0              20370             5470           2385               145
# 1               3131              506            381                 9
# 2               4024              264             87               323
# 3              40586              640            622              1118
# 4               2016               62             64                13
# ...              ...              ...            ...               ...
# 1332               1                0             17                 0
# 1333               0                1             17                 0
# 1334               2                0             15                 0
# 1335               2                0             16                 0
# 1336               0                0             17                 0
#
#       listed_count                 created_at  ... verified  \
# 0               52  2007-04-06 10:58:22+00:00  ...      NaN
# 1               40  2007-04-30 15:08:42+00:00  ...      NaN
# 2               16  2007-05-01 11:53:40+00:00  ...      NaN
# 3               32  2007-05-15 16:55:16+00:00  ...      NaN
# 4                0  2007-05-13 19:52:00+00:00  ...      NaN
# ...            ...                        ...  ...      ...
# 1332             0  2013-04-30 08:23:57+00:00  ...      NaN
# 1333             0  2013-04-30 08:34:49+00:00  ...      NaN
# 1334             0  2013-04-30 09:21:12+00:00  ...      NaN
# 1335             0  2013-04-30 11:25:11+00:00  ...      NaN
# 1336             0  2013-04-30 12:47:51+00:00  ...      NaN
#
#                                             description              updated  \
# 0     Founder of http://www.screenweek.it & http://w...  2015-02-14 10:54:49
# 1     BSc degree (cum laude) in Computer Engineering...  2015-02-14 10:54:49
# 2                                Cogito ergo bestemmio.  2015-02-14 10:54:49
# 3                  Se la vita ti dà sarde, scapocciale!  2015-02-14 10:54:49
# 4                                        Je me souviens  2015-02-14 10:54:49
# ...                                                 ...                  ...
# 1332  I have been in business onlin and offline for ...  2015-02-14 10:40:01
# 1333                                                NaN  2015-02-14 10:40:01
# 1334                                                NaN  2015-02-14 10:40:01
# 1335                                                NaN  2015-02-14 10:40:01
# 1336  Hello!im a BELIEBER! IM A HUGE FAN OF JUSTIN B...  2015-02-14 10:40:01
#
#      dataset  age_in_days  ratio statuses_count/age  ratio Favorites/age  \
# 0        E13         5822                     3.499                0.025
# 1        E13         5797                     0.540                0.002
# 2        E13         5797                     0.694                0.056
# 3        E13         5782                     7.019                0.193
# 4        E13         5784                     0.349                0.002
# ...      ...          ...                       ...                  ...
# 1332     INT         3606                     0.000                0.000
# 1333     INT         3606                     0.000                0.000
# 1334     INT         3606                     0.001                0.000
# 1335     INT         3606                     0.001                0.000
# 1336     INT         3606                     0.000                0.000
#
#      ratio Friends/Followers length_of_bio  reputation
# 0                      0.436           151    0.696372
# 1                      0.753           104    0.570462
# 2                      0.330            22    0.752137
# 3                      0.972            36    0.507132
# 4                      1.032            14    0.492063
# ...                      ...           ...         ...
# 1332                     inf           158    0.000000
# 1333                  17.000             3    0.055556
# 1334                     inf             3    0.000000
# 1335                     inf             3    0.000000
# 1336                     inf            99    0.000000
#
# [2818 rows x 41 columns]

# %%
X.columns
# Out:
# Index(['Unnamed: 0', 'id', 'name', 'screen_name', 'statuses_count',
#        'followers_count', 'friends_count', 'favourites_count', 'listed_count',
#        'created_at', 'url', 'lang', 'time_zone', 'location', 'default_profile',
#        'default_profile_image', 'geo_enabled', 'profile_image_url',
#        'profile_banner_url', 'profile_use_background_image',
#        'profile_background_image_url_https', 'profile_text_color',
#        'profile_image_url_https', 'profile_sidebar_border_color',
#        'profile_background_tile', 'profile_sidebar_fill_color',
#        'profile_background_image_url', 'profile_background_color',
#        'profile_link_color', 'utc_offset', 'protected', 'verified',
#        'description', 'updated', 'dataset', 'age_in_days',
#        'ratio statuses_count/age', 'ratio Favorites/age',
#        'ratio Friends/Followers', 'length_of_bio', 'reputation'],
#       dtype='object')

# %%
print('Missing sum values:')
columns_to_check = ['Unnamed: 0', 'id', 'name', 'screen_name', 'statuses_count',
       'followers_count', 'friends_count', 'favourites_count', 'listed_count',
       'created_at', 'url', 'lang', 'time_zone', 'location', 'default_profile',
       'default_profile_image', 'geo_enabled', 'profile_image_url',
       'profile_banner_url', 'profile_use_background_image',
       'profile_background_image_url_https', 'profile_text_color',
       'profile_image_url_https', 'profile_sidebar_border_color',
       'profile_background_tile', 'profile_sidebar_fill_color',
       'profile_background_image_url', 'profile_background_color',
       'profile_link_color', 'utc_offset', 'protected', 'verified',
       'description', 'updated', 'dataset', 'age_in_days',
       'ratio statuses_count/age', 'ratio Favorites/age',
       'ratio Friends/Followers', 'length_of_bio', 'reputation']

columns_to_remove = ['Unnamed: 0']

for column in columns_to_check:
    try:
        missing_count = X[column].isnull().sum()
        print(f"{column}: {missing_count}")
        
        # Check if missing count is greater than 2000
        if missing_count > 2000:
            columns_to_remove.append(column)
            print(f"Removing {column} due to more than 2000 missing values.")
    except KeyError:
        # Column having '/' might be causing the issue
        print(f"{column}: Column not found in the DataFrame.")
# Out:
# Missing sum values:
# Unnamed: 0: 0
# id: 0
# name: 0
# screen_name: 0
# statuses_count: 0
# followers_count: 0
# friends_count: 0
# favourites_count: 0
# listed_count: 0
# created_at: 0
# url: 2355
# Removing url due to more than 2000 missing values.
# lang: 0
# time_zone: 1749
# location: 547
# default_profile: 1090
# default_profile_image: 2810
# Removing default_profile_image due to more than 2000 missing values.
# geo_enabled: 2097
# Removing geo_enabled due to more than 2000 missing values.
# profile_image_url: 0
# profile_banner_url: 1831
# profile_use_background_image: 58
# profile_background_image_url_https: 0
# profile_text_color: 0
# profile_image_url_https: 0
# profile_sidebar_border_color: 0
# profile_background_tile: 2329
# Removing profile_background_tile due to more than 2000 missing values.
# profile_sidebar_fill_color: 0
# profile_background_image_url: 0
# profile_background_color: 0
# profile_link_color: 0
# utc_offset: 1749
# protected: 2818
# Removing protected due to more than 2000 missing values.
# verified: 2818
# Removing verified due to more than 2000 missing values.
# description: 271
# updated: 0
# dataset: 0
# age_in_days: 0
# ratio statuses_count/age: 0
# ratio Favorites/age: 0
# ratio Friends/Followers: 1
# length_of_bio: 0
# reputation: 1

# %%
# Remove columns with more than 2000 null values
X = X.drop(columns=columns_to_remove, axis=1)

# Display the DataFrame after removing columns
print("\nDataFrame after removing columns with more than 2000 null values:")
X
# Out:
# DataFrame after removing columns with more than 2000 null values:
#               id              name      screen_name  statuses_count  \
# 0        3610511  Davide Dellacasa           braddd           20370
# 1        5656162    Simone Economo            eKoeS            3131
# 2        5682702            tacone          tacone_            4024
# 3        6067292          alesaura         alesstar           40586
# 4        6015122            Angelo       PerDiletto            2016
# ...          ...               ...              ...             ...
# 1332  1391497074       Verda Marks      VerdaMarks1               1
# 1333  1391544607   Danial Campbell  DanialCampbell2               0
# 1334  1391622127      Maudie Meyer     MaudieMeyer1               2
# 1335  1391832212   Harriett Harvey  HarriettHarvey9               2
# 1336  1391998039   Gillian Wheeler  GillianWheeler3               0
#
#       followers_count  friends_count  favourites_count  listed_count  \
# 0                5470           2385               145            52
# 1                 506            381                 9            40
# 2                 264             87               323            16
# 3                 640            622              1118            32
# 4                  62             64                13             0
# ...               ...            ...               ...           ...
# 1332                0             17                 0             0
# 1333                1             17                 0             0
# 1334                0             15                 0             0
# 1335                0             16                 0             0
# 1336                0             17                 0             0
#
#                      created_at lang  ... utc_offset  \
# 0     2007-04-06 10:58:22+00:00   it  ...     3600.0
# 1     2007-04-30 15:08:42+00:00   en  ...     3600.0
# 2     2007-05-01 11:53:40+00:00   en  ...     3600.0
# 3     2007-05-15 16:55:16+00:00   en  ...     3600.0
# 4     2007-05-13 19:52:00+00:00   it  ...     3600.0
# ...                         ...  ...  ...        ...
# 1332  2013-04-30 08:23:57+00:00   en  ...        NaN
# 1333  2013-04-30 08:34:49+00:00   en  ...        NaN
# 1334  2013-04-30 09:21:12+00:00   en  ...        NaN
# 1335  2013-04-30 11:25:11+00:00   en  ...        NaN
# 1336  2013-04-30 12:47:51+00:00   en  ...        NaN
#
#                                             description              updated  \
# 0     Founder of http://www.screenweek.it & http://w...  2015-02-14 10:54:49
# 1     BSc degree (cum laude) in Computer Engineering...  2015-02-14 10:54:49
# 2                                Cogito ergo bestemmio.  2015-02-14 10:54:49
# 3                  Se la vita ti dà sarde, scapocciale!  2015-02-14 10:54:49
# 4                                        Je me souviens  2015-02-14 10:54:49
# ...                                                 ...                  ...
# 1332  I have been in business onlin and offline for ...  2015-02-14 10:40:01
# 1333                                                NaN  2015-02-14 10:40:01
# 1334                                                NaN  2015-02-14 10:40:01
# 1335                                                NaN  2015-02-14 10:40:01
# 1336  Hello!im a BELIEBER! IM A HUGE FAN OF JUSTIN B...  2015-02-14 10:40:01
#
#      dataset age_in_days  ratio statuses_count/age ratio Favorites/age  \
# 0        E13        5822                     3.499               0.025
# 1        E13        5797                     0.540               0.002
# 2        E13        5797                     0.694               0.056
# 3        E13        5782                     7.019               0.193
# 4        E13        5784                     0.349               0.002
# ...      ...         ...                       ...                 ...
# 1332     INT        3606                     0.000               0.000
# 1333     INT        3606                     0.000               0.000
# 1334     INT        3606                     0.001               0.000
# 1335     INT        3606                     0.001               0.000
# 1336     INT        3606                     0.000               0.000
#
#      ratio Friends/Followers length_of_bio reputation
# 0                      0.436           151   0.696372
# 1                      0.753           104   0.570462
# 2                      0.330            22   0.752137
# 3                      0.972            36   0.507132
# 4                      1.032            14   0.492063
# ...                      ...           ...        ...
# 1332                     inf           158   0.000000
# 1333                  17.000             3   0.055556
# 1334                     inf             3   0.000000
# 1335                     inf             3   0.000000
# 1336                     inf            99   0.000000
#
# [2818 rows x 34 columns]

# %%
# Assigning False '0' to fake_users list and true '1' to real_users list
y = len(fake_users)*[0]+len(real_users)*[1]

# %%
# Create a detector instance
sex_predictor = gender.Detector(case_sensitive=False)

# Extract the first name and predict their genders
X['First Name'] = X['name'].str.split(' ').str.get(0)

# To handle names that have unrecognized characters
def clean_name(name):
    cleaned_name = re.sub(r'[^\x00-\x7F]+', '', name)
    return cleaned_name

# Clean the 'First Name' values
X['First Name'] = X['First Name'].apply(clean_name)

X['Predicted Sex'] = X['First Name'].apply(sex_predictor.get_gender)

# Mapping of Gender
sex_dict = {'female': -2, 'mostly_female': -1, 'unknown': 0, 'mostly_male': 1, 'male': 2}

# Handle 'unknown' values
X['Predicted Sex'] = X['Predicted Sex'].apply(lambda x: 'unknown' if x == 'andy' else x)

# Map the predicted genders to codes
X['Sex Code'] = X['Predicted Sex'].map(sex_dict).astype(int)

# %%
X.sample(5)
# Out:
#              id                name      screen_name  statuses_count  \
# 658   365383515     scienziatopazzo   scienziatopazz            3061
# 1226  601192738  Marcello Colaiezzi  marcellocolaiez             574
# 353   616301301      Aileen Gilmore      gilmorekcdu              60
# 837   425908255        Pamela Rizzo         Pam_Pada             110
# 933   446083368    Veronica Ferrari         vero_frr             558
#
#       followers_count  friends_count  favourites_count  listed_count  \
# 658                86             95                 6             0
# 1226              112            359                39             0
# 353                20            564                 0             0
# 837                56            245                 0             0
# 933               111            118                 8             0
#
#                      created_at lang  ... dataset age_in_days  \
# 658   2011-08-31 10:37:53+00:00   it  ...     E13        4214
# 1226  2012-06-06 18:37:23+00:00   it  ...     E13        3933
# 353   2012-06-23 15:48:47+00:00   en  ...     INT        3916
# 837   2011-12-01 15:55:56+00:00   it  ...     E13        4121
# 933   2011-12-25 08:33:51+00:00   it  ...     E13        4098
#
#       ratio statuses_count/age ratio Favorites/age ratio Friends/Followers  \
# 658                      0.726               0.001                   1.105
# 1226                     0.146               0.010                   3.205
# 353                      0.015               0.000                  28.200
# 837                      0.027               0.000                   4.375
# 933                      0.136               0.002                   1.063
#
#       length_of_bio reputation       First Name Predicted Sex Sex Code
# 658              73   0.475138  scienziatopazzo       unknown        0
# 1226             27   0.237792         Marcello          male        2
# 353             158   0.034247           Aileen        female       -2
# 837              59   0.186047           Pamela        female       -2
# 933              19   0.484716         Veronica        female       -2
#
# [5 rows x 37 columns]

# %%
# Create a mapping of unique 'lang' values to codes
lang_list = list(enumerate(np.unique(X['lang'])))
lang_dict = {name: i for i, name in lang_list}

lang_dict
# Out:
# {'de': 0, 'en': 1, 'es': 2, 'fr': 3, 'gl': 4, 'it': 5, 'nl': 6, 'tr': 7}

# %%
# Map 'lang' values to 'lang_code' and convert to integers
X['lang_code'] = X['lang'].map(lambda lang: lang_dict[lang]).astype(int)

# Feature Extraction from columns
feature_columns_to_use = ['Sex Code','statuses_count','followers_count','friends_count','favourites_count','listed_count','lang_code']

# Create a new DataFrame with selected feature columns
X = X[feature_columns_to_use]

# %%
x = X 
x
# Out:
#       Sex Code  statuses_count  followers_count  friends_count  \
# 0            2           20370             5470           2385
# 1           -2            3131              506            381
# 2            0            4024              264             87
# 3            0           40586              640            622
# 4            2            2016               62             64
# ...        ...             ...              ...            ...
# 1332        -2               1                0             17
# 1333         2               0                1             17
# 1334        -2               2                0             15
# 1335        -2               2                0             16
# 1336        -2               0                0             17
#
#       favourites_count  listed_count  lang_code
# 0                  145            52          5
# 1                    9            40          1
# 2                  323            16          1
# 3                 1118            32          1
# 4                   13             0          5
# ...                ...           ...        ...
# 1332                 0             0          1
# 1333                 0             0          1
# 1334                 0             0          1
# 1335                 0             0          1
# 1336                 0             0          1
#
# [2818 rows x 7 columns]

# %% [markdown]
# MODEL TRAINING

# %%
import joblib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
pip install xgboost
# Out:
# Requirement already satisfied: xgboost in c:\users\sunny kumar\anaconda3\lib\site-packages (2.1.4)
# Requirement already satisfied: numpy in c:\users\sunny kumar\anaconda3\lib\site-packages (from xgboost) (1.26.4)
# Requirement already satisfied: scipy in c:\users\sunny kumar\anaconda3\lib\site-packages (from xgboost) (1.13.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn import impute
from sklearn import model_selection
from sklearn import metrics
from sklearn import preprocessing
from sklearn.metrics import roc_curve, auc, accuracy_score, classification_report, confusion_matrix, accuracy_score, make_scorer
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import StratifiedKFold, train_test_split, GridSearchCV, learning_curve
from xgboost import XGBClassifier
from sklearn.svm import SVC

# %% [markdown]
# plot Learning curve

# %%
import numpy as np

# %%
def plot_learning_curve(estimator, title, X, y, ylim=None, cv=None,
                        n_jobs=1, train_sizes=np.linspace(.1, 1.0, 5)):
    """
    Generate a learning curve plot for a machine learning model.

    Parameters:
    - estimator: The machine learning model to evaluate.
    - title: The title of the plot.
    - X: The input features.
    - y: The target variable.
    - ylim: Tuple, optional, the y-axis limits.
    - cv: Cross-validation strategy. None by default.
    - n_jobs: Number of jobs to run in parallel for cross-validation.
    - train_sizes: Array of training set sizes.

    Returns:
    - Matplotlib plot object.
    """

    plt.figure()
    plt.title(title)

    if ylim is not None:
        plt.ylim(*ylim)

    plt.xlabel("Training examples")
    plt.ylabel("Score")
    
    # Generate learning curves using the learning_curve function
    train_sizes, train_scores, test_scores = learning_curve(
        estimator, X, y, cv=cv, n_jobs=n_jobs, train_sizes=train_sizes)
    
    # Calculate mean and standard deviation of training scores
    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    
    # Calculate mean and standard deviation of test scores
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)
    
    plt.grid()
    plt.fill_between(train_sizes, train_scores_mean - train_scores_std,
                     train_scores_mean + train_scores_std, alpha=0.1,
                     color="r") 
    plt.fill_between(train_sizes, test_scores_mean - test_scores_std,
                     test_scores_mean + test_scores_std, alpha=0.1, color="g")
    
    plt.plot(train_sizes, train_scores_mean, 'o-', color="r",
             label="Training score")
    plt.plot(train_sizes, test_scores_mean, 'o-', color="g",
             label="Cross-validation score")

    plt.legend(loc="best")
    return plt

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import learning_curve

def plot_learning_curve(estimator, title, X, y, ylim=None, cv=None,
                        n_jobs=1, train_sizes=np.linspace(.1, 1.0, 5)):
    """
    Generate a learning curve plot for a machine learning model.

    Parameters:
    - estimator: The machine learning model to evaluate.
    - title: The title of the plot.
    - X: The input features.
    - y: The target variable.
    - ylim: Tuple, optional, the y-axis limits.
    - cv: Cross-validation strategy. None by default.
    - n_jobs: Number of jobs to run in parallel for cross-validation.
    - train_sizes: Array of training set sizes.

    Returns:
    - Matplotlib plot object.
    """

    plt.figure()
    plt.title(title)

    if ylim is not None:
        plt.ylim(*ylim)

    plt.xlabel("Training examples")
    plt.ylabel("Score")
    
    # Generate learning curves using the learning_curve function
    train_sizes, train_scores, test_scores = learning_curve(
        estimator, X, y, cv=cv, n_jobs=n_jobs, train_sizes=train_sizes)
    
    # Calculate mean and standard deviation of training scores
    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    
    # Calculate mean and standard deviation of test scores
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)
    
    plt.grid()
    plt.fill_between(train_sizes, train_scores_mean - train_scores_std,
                     train_scores_mean + train_scores_std, alpha=0.1,
                     color="r") 
    plt.fill_between(train_sizes, test_scores_mean - test_scores_std,
                     test_scores_mean + test_scores_std, alpha=0.1, color="g")
    
    plt.plot(train_sizes, train_scores_mean, 'o-', color="r",
             label="Training score")
    plt.plot(train_sizes, test_scores_mean, 'o-', color="g",
             label="Cross-validation score")

    plt.legend(loc="best")
    return plt

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\sunny kumar\anaconda3\lib\site-packages (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\sunny kumar\anaconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\sunny kumar\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\sunny kumar\anaconda3\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\sunny kumar\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.23 in c:\users\sunny kumar\anaconda3\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\sunny kumar\appdata\roaming\python\python312\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\sunny kumar\anaconda3\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\sunny kumar\anaconda3\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\sunny kumar\appdata\roaming\python\python312\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\sunny kumar\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Display mean and standard deviation of pre processed dataset
X.describe()
# Out:
#           Sex Code  statuses_count  followers_count  friends_count  \
# count  2818.000000     2818.000000      2818.000000    2818.000000
# mean     -0.194109     1672.198368       371.105039     395.363023
# std       1.688654     4884.669157      8022.631339     465.694322
# min      -2.000000        0.000000         0.000000       0.000000
# 25%      -2.000000       35.000000        17.000000     168.000000
# 50%       0.000000       77.000000        26.000000     306.000000
# 75%       2.000000     1087.750000       111.000000     519.000000
# max       2.000000    79876.000000    408372.000000   12773.000000
#
#        favourites_count  listed_count    lang_code
# count       2818.000000   2818.000000  2818.000000
# mean         234.541164      2.818666     2.851313
# std         1445.847248     23.480430     1.992950
# min            0.000000      0.000000     0.000000
# 25%            0.000000      0.000000     1.000000
# 50%            0.000000      0.000000     1.000000
# 75%           37.000000      1.000000     5.000000
# max        44349.000000    744.000000     7.000000

# %% [markdown]
# RANDOM FOREST CLASSIFIER

# %%
def train(X_train,y_train,X_test, y_test):
    """ Trains and predicts dataset with a Random Forest classifier """
    
    filename = 'model.ckpt'
    clf=RandomForestClassifier(n_estimators=40,oob_score=True)
    clf.fit(X_train,y_train)
    joblib.dump(clf, filename)
    print("The best classifier is: ",clf)

    # Estimate score
    scores = model_selection.cross_val_score(clf, X_train,y_train, cv=5)
    print (scores)
    print('Estimated score: %0.5f (+/- %0.5f)' % (scores.mean(), scores.std() / 2))
    title = 'Learning Curves (Random Forest)'
    plot_learning_curve(clf, title, X_train, y_train, cv=5)
    plt.show()

    # Predict 
    y_pred = clf.predict(X_test)
    return y_test, y_pred

# %% [markdown]
# RANDOM FOREST CLASSIFIER (CUSTOM HYPERPARAMETERS)

# %%
def train(X_train, y_train, X_test, y_test):
    filename = 'model.ckpt'
    param_grid = {
        'n_estimators': [20, 40, 60, 80, 100],
        'max_depth': [None, 10, 20, 30, 40],
        'min_samples_split': [2, 5, 10],
        'min_samples_leaf': [1, 2, 4]
    }

    rf_clf = RandomForestClassifier(oob_score=True)
    scorer = make_scorer(accuracy_score)
    grid_search = GridSearchCV(rf_clf, param_grid, cv=5, scoring=scorer, n_jobs=-1)
    grid_search.fit(X_train, y_train)
    
    # Save the best model to a file
    best_rf_model = grid_search.best_estimator_
    joblib.dump(best_rf_model, filename)
        
    print("Training Datasets using Random Forest Classifier")
    print("Best Hyperparameters:", grid_search.best_params_)
    y_pred = best_rf_model.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    print("Accuracy of the Best Model:", accuracy)
    print("Out-of-Bag Score:", best_rf_model.oob_score_)
    
    title = 'Learning Curves (Random Forest)'
    plot_learning_curve(best_rf_model, title, X_train, y_train, cv=5)
    plt.show()

    return y_test, y_pred

# %% [markdown]
# SUPPORT VECTOR MACHINE (SVM CLASSIFIER-CUSTOM HYPERPARAMETERS)

# %%
def train(X_train, y_train, X_test, y_test):
    filename = 'model.ckpt'
    param_grid = {
        'C': [0.1, 1, 10],
        'gamma': [0.01, 0.1, 1],
        'kernel': ['rbf']
    }

    svm_clf = SVC()
    scorer = make_scorer(accuracy_score)
    grid_search = GridSearchCV(svm_clf, param_grid, cv=5, scoring=scorer, n_jobs=-1)
    grid_search.fit(X_train, y_train)
    
    best_svm_model = grid_search.best_estimator_
    joblib.dump(best_svm_model, filename)

    print("Training Datasets using SVC")
    print("Best Hyperparameters:", grid_search.best_params_)
    y_pred = best_svm_model.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    print("Accuracy of the Best Model:", accuracy)

    title = 'Learning Curves (SVM)'
    plot_learning_curve(best_svm_model, title, X_train, y_train, cv=5)
    plt.show()
    
    return y_test, y_pred

# %% [markdown]
# Xtreme Gradient Boosting(XGB-Custom Hyperparameters)

# %%
def train(X_train, y_train, X_test, y_test):
    filename = 'model.ckpt'
    param_grid = {
        'n_estimators': [20, 40, 60],
        'max_depth': [3, 5, 7],
        'learning_rate': [0.1, 0.2, 0.3],
        'subsample': [0.8, 0.9, 1.0],
        'min_child_weight': [1, 3, 5]
    }

    xgb_clf = XGBClassifier()
    scorer = make_scorer(accuracy_score)
    grid_search = GridSearchCV(xgb_clf, param_grid, cv=5, scoring=scorer, n_jobs=-1)
    grid_search.fit(X_train, y_train)
    
    best_xgb_model = grid_search.best_estimator_
    joblib.dump(best_xgb_model, filename)

    print("Training Datasets using XGBoost Classifier")
    print("Best Hyperparameters:", grid_search.best_params_)
    y_pred = best_xgb_model.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    print("Accuracy of the Best Model:", accuracy)
    
    title = 'Learning Curves (XGBoost)'
    plot_learning_curve(best_xgb_model, title, X_train, y_train, cv=5)
    plt.show()

    return y_test, y_pred

# %% [markdown]
#  Before splitting datasets and starting to training a model, choose one of the classifier trainer model function and re-run

# %%
# Perform train-test datasets  split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=44)

# %%
# Start training models
y_test, y_pred = train(X_train, y_train, X_test, y_test)
# Out:
# Training Datasets using XGBoost Classifier
# Best Hyperparameters: {'learning_rate': 0.2, 'max_depth': 5, 'min_child_weight': 5, 'n_estimators': 20, 'subsample': 0.9}
# Accuracy of the Best Model: 0.9414893617021277

# %%
# Assuming 'model' is your trained model

# Save the model as a .h5 file (HDF5 format)
model.save('my_model.h5')

# This will save the model in the current directory of the notebook

# %% [markdown]
# Plot Confusion Matrix

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

def plot_confusion_matrix(cm, title='Confusion matrix', cmap=plt.cm.Blues):
    target_names = ['Fake', 'Genuine(Real)']
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    
    tick_marks = np.arange(len(target_names))
    plt.xticks(tick_marks, target_names)
    plt.yticks(tick_marks, target_names)
    
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.show()  # Add this line to display the plot

# Assuming you have your y_test and y_pred values
cm = confusion_matrix(y_test, y_pred)

print('Confusion Matrix [without Normalization]')
print(cm)
# Out:
# Confusion Matrix [without Normalization]
# [[264   4]
#  [ 29 267]]

# %%
# Plot the confusion matrix
plot_confusion_matrix(cm)

# %%
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

print('Confusion Matrix[with Normalization]')
print(cm_normalized)
# Out:
# Confusion Matrix[with Normalization]
# [[0.98507463 0.01492537]
#  [0.09797297 0.90202703]]

# %%
plot_confusion_matrix(cm_normalized, title='Normalized confusion matrix')

# %% [markdown]
# Plot reverse Operating Characteristic(Roc ) curve

# %%
def plot_roc_curve(y_test, y_pred):
    false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test, y_pred)

    print("False Positive rate: ",false_positive_rate)
    print("True Positive rate: ",true_positive_rate)

    roc_auc = auc(false_positive_rate, true_positive_rate)

    plt.title('Receiver Operating Characteristic')
    plt.plot(false_positive_rate, true_positive_rate, 'b',
    label='AUC = %0.2f'% roc_auc)
    plt.legend(loc='lower right')
    plt.plot([0,1],[0,1],'r--')
    plt.xlim([-0.1,1.2])
    plt.ylim([-0.1,1.2])
    plt.ylabel('True Positive Rate')
    plt.xlabel('False Positive Rate')
    plt.show()

# %%
plot_roc_curve(y_test, y_pred)
# Out:
# False Positive rate:  [0.         0.01492537 1.        ]
# True Positive rate:  [0.         0.90202703 1.        ]

# %%
pip install jupyter nbconvert flask
# Out:
# Requirement already satisfied: jupyter in c:\users\sunny kumar\appdata\roaming\python\python312\site-packages (1.1.1)
# Requirement already satisfied: nbconvert in c:\users\sunny kumar\appdata\roaming\python\python312\site-packages (7.16.6)
# Requirement already satisfied: flask in c:\users\sunny kumar\appdata\roaming\python\python312\site-packages (3.1.0)
# Requirement already satisfied: notebook in c:\users\sunny kumar\appdata\roaming\python\python312\site-packages (from jupyter) (7.3.2)
# Requirement already satisfied: jupyter-console in c:\users\sunny kumar\appdata\roaming\python\python312\site-packages (from jupyter) (6.6.3)
# Requirement already satisfied: ipykernel in c:\users\sunny kumar\appdata\roaming\python\python312\site-packages (from jupyter) (6.29.5)
# Requirement already satisfied: ipywidgets in c:\users\sunny kumar\appdata\roaming\python\python312\site-packages (from jupyter) (8.1.5)
# Requirement already satisfied: jupyterlab in c:\users\sunny kumar\appdata\roaming\python\python312\site-packages (from jupyter) (4.3.5)
# Requirement already satisfied: beautifulsoup4 in c:\users\sunny kumar\appdata\roaming\python\python312\site-packages (from nbconvert) (4.13.3)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\sunny kumar\appdata\roaming\python\python312\site-packages (from bleach[css]!=5.0.0->nbconvert) (6.2.0)
# Requirement already satisfied: defusedxml in c:\users\sunny kumar\appdata\roaming\python\python312\site-packages (from nbconvert) (0.7.1)
# Requirement already satisfied: jinja2>=3.0 in c:\users\sunny kumar\appdata\roaming\python\python312\site-packages (from nbconvert) (3.1.5)
# Requirement already satisfied: jupyter-core>=4.7 in c:\users\sunny kumar\appdata\roaming\python\python312\site-packages (from nbconvert) (5.7.2)
# Requirement already satisfied: jupyterlab-pygments in c:\users\sunny kumar\appdata\roaming\python\python312\site-packages (from nbconvert) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in c:\users\sunny kumar\appdata\roaming\python\python312\site-packages (from nbconvert) (3.0.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\sunny kumar\appdata\roaming\python\python312\site-packages (from nbconvert) (3.1.1)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\sunny kumar\appdata\roaming\python\python312\site-packages (from nbconvert) (0.10.2)
# Requirement already satisfied: nbformat>=5.7 in c:\users\sunny kumar\appdata\roaming\python\python312\site-packages (from nbconvert) (5.10.4)
# Requirement already satisfied: packaging in c:\users\sunny kumar\appdata\roaming\python\python312\site-packages (from nbconvert) (24.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\sunny kumar\appdata\roaming\python\python312\site-packages (from nbconvert) (1.5.1)
# Requirement already satisfied: pygments>=2.4.1 in c:\users\sunny kumar\appdata\roaming\python\python312\site-packages (from nbconvert) (2.19.1)
# Requirement already satisfied: traitlets>=5.1 in c:\users\sunny kumar\appdata\roaming\python\python312\site-packages (from nbconvert) (5.14.3)
# Requirement already satisfied: Werkzeug>=3.1 in c:\users\sunny kumar\appdata\roaming\python\python312\site-packages (from flask) (3.1.3)
# Requirement already satisfied: itsdangerous>=2.2 in c:\users\sunny kumar\appdata\roaming\python\python312\site-packages (from flask) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in c:\users\sunny kumar\appdata\roaming\python\python312\site-packages (from flask) (8.1.8)
# Requirement already satisfied: blinker>=1.9 in c:\users\sunny kumar\appdata\roaming\python\python312\site-packages (from flask) (1.9.0)
# Requirement already satisfied: webencodings in c:\users\sunny kumar\appdata\roaming\python\python312\site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in c:\users\sunny kumar\appdata\roaming\python\python312\site-packages (from bleach[css]!=5.0.0->nbconvert) (1.4.0)
# Requirement already satisfied: colorama in c:\users\sunny kumar\appdata\roaming\python\python312\site-packages (from click>=8.1.3->flask) (0.4.6)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\sunny kumar\appdata\roaming\python\python312\site-packages (from jupyter-core>=4.7->nbconvert) (4.3.6)
# Requirement already satisfied: pywin32>=300 in c:\users\sunny kumar\appdata\roaming\python\python312\site-packages (from jupyter-core>=4.7->nbconvert) (308)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\sunny kumar\appdata\roaming\python\python312\site-packages (from nbclient>=0.5.0->nbconvert) (8.6.3)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\sunny kumar\appdata\roaming\python\python312\site-packages (from nbformat>=5.7->nbconvert) (2.21.1)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\sunny kumar\appdata\roaming\python\python312\site-packages (from nbformat>=5.7->nbconvert) (4.23.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\sunny kumar\appdata\roaming\python\python312\site-packages (from beautifulsoup4->nbconvert) (2.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\sunny kumar\appdata\roaming\python\python312\site-packages (from beautifulsoup4->nbconvert) (4.12.2)
# Requirement already satisfied: comm>=0.1.1 in c:\users\sunny kumar\appdata\roaming\python\python312\site-packages (from ipykernel->jupyter) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\sunny kumar\appdata\roaming\python\python312\site-packages (from ipykernel->jupyter) (1.8.12)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\sunny kumar\appdata\roaming\python\python312\site-packages (from ipykernel->jupyter) (8.32.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\sunny kumar\appdata\roaming\python\python312\site-packages (from ipykernel->jupyter) (0.1.7)
# Requirement already satisfied: nest-asyncio in c:\users\sunny kumar\appdata\roaming\python\python312\site-packages (from ipykernel->jupyter) (1.6.0)
# Requirement already satisfied: psutil in c:\users\sunny kumar\appdata\roaming\python\python312\site-packages (from ipykernel->jupyter) (7.0.0)
# Requirement already satisfied: pyzmq>=24 in c:\users\sunny kumar\appdata\roaming\python\python312\site-packages (from ipykernel->jupyter) (26.2.1)
# Requirement already satisfied: tornado>=6.1 in c:\users\sunny kumar\appdata\roaming\python\python312\site-packages (from ipykernel->jupyter) (6.4.2)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in c:\users\sunny kumar\appdata\roaming\python\python312\site-packages (from ipywidgets->jupyter) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in c:\users\sunny kumar\appdata\roaming\python\python312\site-packages (from ipywidgets->jupyter) (3.0.13)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in c:\users\sunny kumar\appdata\roaming\python\python312\site-packages (from jupyter-console->jupyter) (3.0.50)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\sunny kumar\appdata\roaming\python\python312\site-packages (from jupyterlab->jupyter) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in c:\users\sunny kumar\appdata\roaming\python\python312\site-packages (from jupyterlab->jupyter) (0.28.1)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\sunny kumar\appdata\roaming\python\python312\site-packages (from jupyterlab->jupyter) (2.2.5)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\sunny kumar\appdata\roaming\python\python312\site-packages (from jupyterlab->jupyter) (2.15.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in c:\users\sunny kumar\appdata\roaming\python\python312\site-packages (from jupyterlab->jupyter) (2.27.3)
# Requirement already satisfied: notebook-shim>=0.2 in c:\users\sunny kumar\appdata\roaming\python\python312\site-packages (from jupyterlab->jupyter) (0.2.4)
# Requirement already satisfied: setuptools>=40.8.0 in c:\users\sunny kumar\appdata\roaming\python\python312\site-packages (from jupyterlab->jupyter) (75.8.0)
# Requirement already satisfied: anyio in c:\users\sunny kumar\appdata\roaming\python\python312\site-packages (from httpx>=0.25.0->jupyterlab->jupyter) (4.8.0)
# Requirement already satisfied: certifi in c:\users\sunny kumar\appdata\roaming\python\python312\site-packages (from httpx>=0.25.0->jupyterlab->jupyter) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in c:\users\sunny kumar\appdata\roaming\python\python312\site-packages (from httpx>=0.25.0->jupyterlab->jupyter) (1.0.7)
# Requirement already satisfied: idna in c:\users\sunny kumar\appdata\roaming\python\python312\site-packages (from httpx>=0.25.0->jupyterlab->jupyter) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\sunny kumar\appdata\roaming\python\python312\site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab->jupyter) (0.14.0)
# Requirement already satisfied: decorator in c:\users\sunny kumar\appdata\roaming\python\python312\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\sunny kumar\appdata\roaming\python\python312\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.19.2)
# Requirement already satisfied: stack_data in c:\users\sunny kumar\appdata\roaming\python\python312\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.6.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\sunny kumar\appdata\roaming\python\python312\site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert) (25.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\sunny kumar\appdata\roaming\python\python312\site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\sunny kumar\appdata\roaming\python\python312\site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\sunny kumar\appdata\roaming\python\python312\site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert) (0.22.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\sunny kumar\appdata\roaming\python\python312\site-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert) (2.9.0.post0)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\sunny kumar\appdata\roaming\python\python312\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (23.1.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in c:\users\sunny kumar\appdata\roaming\python\python312\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\sunny kumar\appdata\roaming\python\python312\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.5.3)
# Requirement already satisfied: overrides>=5.0 in c:\users\sunny kumar\appdata\roaming\python\python312\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\sunny kumar\appdata\roaming\python\python312\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.21.1)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\sunny kumar\appdata\roaming\python\python312\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.0.15)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\sunny kumar\appdata\roaming\python\python312\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\sunny kumar\appdata\roaming\python\python312\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\sunny kumar\appdata\roaming\python\python312\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.8.0)
# Requirement already satisfied: babel>=2.10 in c:\users\sunny kumar\appdata\roaming\python\python312\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\sunny kumar\appdata\roaming\python\python312\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (0.10.0)
# Requirement already satisfied: requests>=2.31 in c:\users\sunny kumar\appdata\roaming\python\python312\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2.32.3)
# Requirement already satisfied: wcwidth in c:\users\sunny kumar\appdata\roaming\python\python312\site-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter) (0.2.13)
# Requirement already satisfied: sniffio>=1.1 in c:\users\sunny kumar\appdata\roaming\python\python312\site-packages (from anyio->httpx>=0.25.0->jupyterlab->jupyter) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\sunny kumar\appdata\roaming\python\python312\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (21.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\sunny kumar\appdata\roaming\python\python312\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter) (0.8.4)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\sunny kumar\appdata\roaming\python\python312\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (3.2.1)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\sunny kumar\appdata\roaming\python\python312\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (6.0.2)
# Requirement already satisfied: rfc3339-validator in c:\users\sunny kumar\appdata\roaming\python\python312\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\sunny kumar\appdata\roaming\python\python312\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.1.1)
# Requirement already satisfied: six>=1.5 in c:\users\sunny kumar\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sunny kumar\appdata\roaming\python\python312\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sunny kumar\appdata\roaming\python\python312\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2.3.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\sunny kumar\appdata\roaming\python\python312\site-packages (from stack_data->ipython>=7.23.1->ipykernel->jupyter) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\sunny kumar\appdata\roaming\python\python312\site-packages (from stack_data->ipython>=7.23.1->ipykernel->jupyter) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\sunny kumar\appdata\roaming\python\python312\site-packages (from stack_data->ipython>=7.23.1->ipykernel->jupyter) (0.2.3)
# Requirement already satisfied: fqdn in c:\users\sunny kumar\appdata\roaming\python\python312\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\sunny kumar\appdata\roaming\python\python312\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\sunny kumar\appdata\roaming\python\python312\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (3.0.0)
# Requirement already satisfied: uri-template in c:\users\sunny kumar\appdata\roaming\python\python312\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in c:\users\sunny kumar\appdata\roaming\python\python312\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (24.11.1)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\sunny kumar\appdata\roaming\python\python312\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\sunny kumar\appdata\roaming\python\python312\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.22)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\sunny kumar\appdata\roaming\python\python312\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in c:\users\sunny kumar\appdata\roaming\python\python312\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.9.0.20241206)
# Note: you may need to restart the kernel to use updated packages.
